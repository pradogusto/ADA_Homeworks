# %%
import requests
import pandas as pd 
from bs4 import BeautifulSoup
import csv
# Pour le test statistique
import scipy.stats as stats
import math
import numpy as np

#cols = ['Period', 'Période pédagogique', 'Civilité', 'Nom et prénom',
#            'Orientation Bachelor', 'Orientation Master', 'Filière opt.',
#            'Mineur', 'Statut', 'Type', 'Ecole Echange', 'Sciper']

cols = ['Période académique', 'Période pédagogique', 'Civilité', 'Nom et prénom','Sciper','Mineur','Spécialisation','Statut']
ALL_DATA = pd.DataFrame(columns=cols)

# %%
def arrange_student(student_tags) : 
    
    student = {}
    
    if(len(student_tags)!=0) : 
        
        student = {}
    
        student['Civilité'] = student_tags[0].contents[0]
        student['Nom et prénom'] = student_tags[1].contents[0]
        student['Sciper'] = student_tags[10].contents[0]
        student['Statut'] = student_tags[7].contents[0]
        
        if(len(student_tags[4].contents)!=0) : 
            student['Spécialisation'] = student_tags[4].contents[0]
        
        if(len(student_tags[6].contents)!=0) : 
            student['Mineur'] = student_tags[6].contents[0]
            
        
    return student

# %%
#ACQUISITION DES FILTRES SOUS FORME DE DICTIONNAIRE : OK 

url1 = 'http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.filter?ww_i_reportModel=133685247'
r1 = requests.get(url1)
soup1 = BeautifulSoup(r1.content,"lxml")

filters = {}

for filt in soup1.findAll("select"):
    
    filter_values = {}
        
    for option in filt.findAll("option"):
       
        if(option['value']!='null') : #juste pr éviter le premier element ki est vide
            filter_values[option.contents[0]] = option['value']
    
    filter_values[''] = 'null'
    filters[filt['name']] = filter_values

# %%
#URL avec lequel on va faire les requêtes et fichier csv qu'on va créer 

url2 = 'http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.html?'

#Paramètres qu'on va passer aux filtres
fixed_params = {}
fixed_params['ww_x_GPS'] = '-1'
fixed_params['ww_i_reportModel'] = '133685247'
fixed_params['ww_i_reportModelXsl'] = '133685270'
fixed_params['ww_x_UNITE_ACAD'] = filters['ww_x_UNITE_ACAD']['Informatique']

#Truc ou on va stocker tt les etudiants de master quelque soit leur niveau

master_students = []

for periode_pedagogique in ['Master semestre 1','Master semestre 2','Master semestre 3',
                            'Projet Master automne','Projet Master printemps'] :

    for periode_academique in filters['ww_x_PERIODE_ACAD'].keys() : 
        
        if(periode_academique != '') :
    
            parameters = fixed_params.copy()
            parameters['ww_x_PERIODE_PEDAGO'] = filters['ww_x_PERIODE_PEDAGO'][periode_pedagogique]
            parameters['ww_x_PERIODE_ACAD'] = filters['ww_x_PERIODE_ACAD'][periode_academique]        
            
            req = requests.get(url2,params=parameters)
            soup = BeautifulSoup(req.content,"lxml")
            
            
            for row in soup.find('table').contents[2:] : #on commence 2ème ligne pasque les premières c'est des headers
       
                s = arrange_student(row.findAll('td'))
                s['Période académique'] = periode_academique
                s['Période pédagogique'] = periode_pedagogique
                master_students.append(s)

# %%
for student in master_students : 
    ALL_DATA = ALL_DATA.append(pd.Series(student), ignore_index=True)
ALL_DATA=ALL_DATA = ALL_DATA.drop_duplicates()

# %%
ALL_DATA=ALL_DATA.sort_values('Nom et prénom')
NEW_ALL_DATA=ALL_DATA.set_index(['Nom et prénom'])
NEW_ALL_DATA
# Aeberhard François-Xavier                                                    NaN
# Aeberhard François-Xavier                                                    NaN
# Aeberhard François-Xavier                                                    NaN
# Aeberhard François-Xavier                                                    NaN
# Aeby Prisca                                                                  NaN
# Aeby Prisca                                                                  NaN
# Aeby Prisca                                                                  NaN
# Agapiou Stylianos                                                            NaN
# Agarwal Megha                                                                NaN
# Agarwal Megha                                                                NaN
# Agarwal Megha                                                                NaN
# Ahmed Fayzan                                        Mineur en Neuroprosthétiques
# Ahmed Fayzan                                        Mineur en Neuroprosthétiques
# Ahmed Fayzan                                                                 NaN
# Aiulfi Loris Sandro                                                          NaN
# Alfonso Peterssen Alfonso                                                    NaN
# ...                                                                          ...
# Zoller Roman                                                                 NaN
# Zommerfelds Christian Georges  Mineur en Management, technologie et entrepren...
# Zommerfelds Christian Georges                                                NaN
# Zommerfelds Christian Georges                                                NaN
# Zommerfelds Christian Georges                                                NaN
# Zommerfelds Christian Georges  Mineur en Management, technologie et entrepren...
# Zotos Panteleimon                                                            NaN
# Zotos Panteleimon                                                            NaN
# Zoveralli Marco                                                              NaN
# Zufferey Damien                                                              NaN
# Zufferey Damien                                                              NaN
# Zufferey Damien                                                              NaN
# Züger Walter                                                                 NaN
# Züger Walter                                                                 NaN
# Zürn Christophe                                                              NaN
# Zürn Christophe                                                              NaN
# Zürn Christophe                                                              NaN
# Zürn Christophe                                                              NaN
# Zürn Christophe                                                              NaN
# del Marmol Syméon Marie J.                                                   NaN
# van Boetzelaer Walid                                                         NaN
# van Boetzelaer Walid                                                         NaN
# van Boetzelaer Walid                                                         NaN
# van Boetzelaer Walid                                                         NaN
# van Boetzelaer Walid                                                         NaN
# van Boetzelaer Walid                                                         NaN
# Önal Cagri                                                                   NaN
# Önal Cagri                                                                   NaN
# Önal Cagri                                                                   NaN
# Önal Cagri                                                                   NaN
#
#                                                Spécialisation   Statut
# Nom et prénom
# Abbadi Hajar                                              NaN  Présent
# Abbadi Hajar                                              NaN  Présent
# Abbadi Hajar                                              NaN  Présent
# Abelenda Diego                 Signals, Images and Interfaces  Présent
# Abelenda Diego                 Signals, Images and Interfaces  Présent
# Abelenda Diego                                            NaN  Présent
# Abelenda Diego                                            NaN  Présent
# Abi Akar Nora                                             NaN  Présent
# Abi Akar Nora                                             NaN  Présent
# Abi Akar Nora                                             NaN  Présent
# Adamsons Valdis                                           NaN  Présent
# Adams Marc Alain                                          NaN  Présent
# Aeberhard François-Xavier                  Internet computing  Présent
# Aeberhard François-Xavier                                 NaN  Présent
# Aeberhard François-Xavier                                 NaN    Stage
# Aeberhard François-Xavier                  Internet computing  Présent
# Aeberhard François-Xavier                                 NaN  Présent
# Aeberhard François-Xavier                                 NaN  Présent
# Aeby Prisca                      Internet Information Systems  Présent
# Aeby Prisca                                               NaN  Présent
# Aeby Prisca                      Internet Information Systems  Présent
# Agapiou Stylianos                                         NaN  Présent
# Agarwal Megha                                             NaN  Présent
# Agarwal Megha                                             NaN    Stage
# Agarwal Megha                                             NaN  Présent
# Ahmed Fayzan                                              NaN  Présent
# Ahmed Fayzan                                              NaN  Présent
# Ahmed Fayzan                                              NaN  Présent
# Aiulfi Loris Sandro                                       NaN  Présent
# Alfonso Peterssen Alfonso             Foundations of Software  Présent
# ...                                                       ...      ...
# Zoller Roman                          Foundations of Software  Présent
# Zommerfelds Christian Georges                             NaN  Présent
# Zommerfelds Christian Georges                             NaN  Présent
# Zommerfelds Christian Georges                             NaN    Stage
# Zommerfelds Christian Georges                             NaN    Congé
# Zommerfelds Christian Georges                             NaN  Présent
# Zotos Panteleimon                                         NaN  Présent
# Zotos Panteleimon                                         NaN  Présent
# Zoveralli Marco                                           NaN  Présent
# Zufferey Damien                       Foundations of Software  Présent
# Zufferey Damien                                           NaN  Présent
# Zufferey Damien                       Foundations of Software  Présent
# Züger Walter                                              NaN    Congé
# Züger Walter                                              NaN    Congé
# Zürn Christophe                                           NaN  Présent
# Zürn Christophe                Signals, Images and Interfaces  Présent
# Zürn Christophe                Signals, Images and Interfaces    Congé
# Zürn Christophe                                           NaN    Congé
# Zürn Christophe                                           NaN    Stage
# del Marmol Syméon Marie J.                                NaN  Présent
# van Boetzelaer Walid                                      NaN  Présent
# van Boetzelaer Walid                                      NaN  Présent
# van Boetzelaer Walid                                      NaN    Congé
# van Boetzelaer Walid                       Internet computing  Présent
# van Boetzelaer Walid                                      NaN    Congé
# van Boetzelaer Walid                       Internet computing  Présent
# Önal Cagri                          Computer Engineering - SP  Présent
# Önal Cagri                          Computer Engineering - SP  Présent
# Önal Cagri                          Computer Engineering - SP    Congé
# Önal Cagri                          Computer Engineering - SP  Présent
#
# [2844 rows x 7 columns]

# %%
cols_result = ['Name','Sex','First year of master', 'Last year of master', 'Time_Master (months)','Spécialisation']
result = pd.DataFrame(columns=cols_result)

n=0
for name in NEW_ALL_DATA.index.drop_duplicates() :
    if(NEW_ALL_DATA.loc[name].shape[0]==7):
        n=n+1
    else:
        
        temp_frame = NEW_ALL_DATA.loc[name]
        # max_year = str(max(temp_frame['Période académique'])).split("-")[1]
        # min_year = str(min(temp_frame['Période académique'])).split("-")[0]
        t = temp_frame.shape[0]*6
        temp = {'Name' : name,'Sex' : str(NEW_ALL_DATA.loc[name]['Civilité'].values[0]) ,'First year of master' :temp_frame['Période académique'].min(),
                'Last year of master' :temp_frame['Période académique'].max() ,'Time_Master (months)' : t,
                'Spécialisation': str(NEW_ALL_DATA.loc[name]['Spécialisation'].values[0])}
        result = result.append(temp, ignore_index=True)
print(n)
# Out:
# 191

# %%
result
# Out:
#                                             Name       Sex  \
# 0                                   Abbadi Hajar    Madame
# 1                                 Abelenda Diego  Monsieur
# 2                                  Abi Akar Nora    Madame
# 3                      Aeberhard François-Xavier  Monsieur
# 4                                    Aeby Prisca    Madame
# 5                                  Agarwal Megha    Madame
# 6                                   Ahmed Fayzan  Monsieur
# 7                    Alnasser Riyadh Abdulaziz M  Monsieur
# 8                                 Alsudairy Sara    Madame
# 9                                 Amiguet Jérôme  Monsieur
# 10   Amorim Afonso Caldeira Da Silva Pedro Maria  Monsieur
# 11                  Anadon Laurent Marie Patrick  Monsieur
# 12                            Anagnostaras David  Monsieur
# 13                    Andreina Sébastien Laurent  Monsieur
# 14                                    Angel Axel  Monsieur
# 15                                  Antic Jelena    Madame
# 16                        Antognini Diego Matteo  Monsieur
# 17                    Aranibar Casas Ivan Wilson  Monsieur
# 758            2007-2008           2007-2008                  12.0
# 759            2014-2015           2016-2017                  30.0
# 760            2010-2011           2011-2012                  24.0
# 761            2015-2016           2016-2017                  12.0
# 762            2014-2015           2015-2016                  18.0
# 763            2010-2011           2011-2012                  24.0
# 764            2012-2013           2013-2014                  18.0
# 765            2011-2012           2011-2012                  12.0
# 766            2011-2012           2012-2013                  24.0
# 767            2011-2012           2011-2012                  12.0
# 768            2014-2015           2016-2017                  30.0
# 769            2014-2015           2015-2016                  18.0
# 770            2007-2008           2007-2008                  12.0
# 771            2011-2012           2012-2013                  18.0
# 772            2010-2011           2011-2012                  24.0
# 773            2015-2016           2016-2017                  18.0
# 774            2007-2008           2007-2008                  12.0
# 775            2011-2012           2012-2013                  24.0
# 776            2014-2015           2016-2017                  30.0
# 777            2011-2012           2012-2013                  18.0
# 778            2010-2011           2012-2013                  36.0
# 779            2013-2014           2015-2016                  30.0
# 780            2008-2009           2008-2009                  12.0
# 781            2007-2008           2008-2009                  18.0
# 782            2008-2009           2008-2009                  12.0
# 783            2011-2012           2013-2014                  30.0
# 784            2009-2010           2011-2012                  36.0
# 785            2009-2010           2010-2011                  24.0
#
#                      Spécialisation
# 0                               nan
# 1    Signals, Images and Interfaces
# 2                               nan
# 3                Internet computing
# 4      Internet Information Systems
# 5                               nan
# 6                               nan
# 7                               nan
# 8                               nan
# 9                               nan
# 10                              nan
# 11                              nan
# 12                              nan
# 13                              nan
# 14                              nan
# 15                              nan
# 16                              nan
# 17                              nan
# 18               Internet computing
# 19                              nan
# 20                              nan
# 21   Signals, Images and Interfaces
# 22                              nan
# 23                              nan
# 24                              nan
# 25                              nan
# 26                              nan
# 27               Internet computing
# 28                              nan
# 29                              nan
# ..                              ...
# 756                             nan
# 757                             nan
# 758                             nan
# 759                             nan
# 760         Foundations of Software
# 761                             nan
# 762                             nan
# 763                             nan
# 764                             nan
# 765                             nan
# 766                             nan
# 767                             nan
# 768                             nan
# 769                             nan
# 770                             nan
# 771                             nan
# 772                             nan
# 773                             nan
# 774                             nan
# 775                             nan
# 776  Signals, Images and Interfaces
# 777         Foundations of Software
# 778         Foundations of Software
# 779                             nan
# 780                             nan
# 781         Foundations of Software
# 782                             nan
# 783                             nan
# 784                             nan
# 785       Computer Engineering - SP
#
# [786 rows x 6 columns]

# %%
result.mean()[0]
# Out:
# 19.977099236641223

# %%
#Temps moyen passé par sexe : 

result_by_sex = result.groupby('Sex')
result_by_sex.mean()
# Out:
#           Time_Master (months)
# Sex
# Madame               20.000000
# Monsieur             19.973568

# %% [markdown]
# Computing arrays for Men/Women Time bachelor values.

# %%
results_men = result[result.Sex=='Monsieur']
results_men.head()
# Out:
#                           Name       Sex First year of master  \
# 1               Abelenda Diego  Monsieur            2010-2011
# 3    Aeberhard François-Xavier  Monsieur            2007-2008
# 6                 Ahmed Fayzan  Monsieur            2013-2014
# 7  Alnasser Riyadh Abdulaziz M  Monsieur            2015-2016
# 9               Amiguet Jérôme  Monsieur            2014-2015
#
#   Last year of master  Time_Master (months)                  Spécialisation
# 1           2011-2012                  24.0  Signals, Images and Interfaces
# 3           2009-2010                  36.0              Internet computing
# 6           2014-2015                  18.0                             nan
# 7           2016-2017                  18.0                             nan
# 9           2016-2017                  30.0                             nan

# %%
men = np.array(results_men['Time_Master (months)'])

# %%
results_women = result[result.Sex=='Madame']
women = np.array(results_women['Time_Master (months)'])

# %% [markdown]
# Doing a Two Sample T-test assuming that both samples (men and women) do not have the same variance. In effect, we don't have information about that.
#
# The null hypothesis is that the mean of both groups are the same. We choose a significant level of 0.05

# %%
stats.ttest_ind(a= men,
                b= women,
                equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.042945428864118659, pvalue=0.96580682435779752)

# %%
result.groupby('Spécialisation').mean()
# Out:
#                                 Time_Master (months)
# Spécialisation
# Biocomputing                               21.600000
# Computer Engineering - SP                  21.750000
# Data Analytics                             17.000000
# Foundations of Software                    23.076923
# Information Security - SP                  30.000000
# Internet Information Systems               18.000000
# Internet computing                         22.875000
# Service science                            24.000000
# Signals, Images and Interfaces             23.454545
# Software Systems                           21.500000
# nan                                        19.089983

# %%
for spe in result['Spécialisation'].drop_duplicates():
    results_spe = result[result.Spécialisation==spe]
    spe_array = np.array(results_spe['Time_Master (months)'])
    print('For the specialisation : ', spe, 'here is the result of the test')
    print(stats.ttest_1samp(a= spe_array,               
                 popmean= result.mean()[0]))
# Out:
# For the specialisation :  nan here is the result of the test
# Ttest_1sampResult(statistic=-3.8395395855081169, pvalue=0.00013663777119937435)
# For the specialisation :  Signals, Images and Interfaces here is the result of the test
# Ttest_1sampResult(statistic=2.2813377137674027, pvalue=0.033067777850080485)
# For the specialisation :  Internet computing here is the result of the test
# Ttest_1sampResult(statistic=4.3423230956270435, pvalue=4.1425696399630932e-05)
# For the specialisation :  Internet Information Systems here is the result of the test
# Ttest_1sampResult(statistic=nan, pvalue=nan)
# For the specialisation :  Software Systems here is the result of the test
# Ttest_1sampResult(statistic=1.108814499579786, pvalue=0.29116420317869074)
# For the specialisation :  Foundations of Software here is the result of the test
# Ttest_1sampResult(statistic=4.1668346300656784, pvalue=0.00011948829252962149)
# For the specialisation :  Biocomputing here is the result of the test
# Ttest_1sampResult(statistic=0.33294212445554883, pvalue=0.75589713061949015)
# For the specialisation :  Computer Engineering - SP here is the result of the test
# Ttest_1sampResult(statistic=1.2344896365102531, pvalue=0.23601106440134367)
# For the specialisation :  Service science here is the result of the test
# Ttest_1sampResult(statistic=0.67048346055979613, pvalue=0.6239866770277398)
# For the specialisation :  Data Analytics here is the result of the test
# Ttest_1sampResult(statistic=-2.977099236641223, pvalue=0.0309030584792938)
# For the specialisation :  Information Security - SP here is the result of the test
# Ttest_1sampResult(statistic=nan, pvalue=nan)
# /Users/Gusto/anaconda/lib/python3.5/site-packages/numpy/core/_methods.py:82: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)

# %% [markdown]
# ON ESSAIE De faire comme si tout le monde avait un projet

# %%
result_copy=result.copy() 
for ind, name in enumerate(ALL_DATA['Période pédagogique']):
        if(name.startswith('Projet')):
            print('true')
            print(ind)
            print(result_copy['Time_Master (months)'])
            
            #result['Time_Master (months)'][ind] -= 6
            #print(result['Time_Master (months)'][ind-1])
            
#ALL_DATA[ALL_DATA['Période pédagogique'].startswith('Projet')]
